# %%
print("hello world")
# Out:
# hello world

# %%
x =10
name ="derric"
pi = 3.14
flag = True
print("Name:",name,"| value of x :",x)
# Out:
# Name: derric | value of x : 10

# %%
a = int("10")
b = float("12.55")
print(type(a),type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
x =10
y = 3.4
name = "teja"
is_active  = True
a,b = 1,2
a,b = b,a #swap
print(a,b)
# Out:
# 2 1

# %%
i = 10 #int
f = 2.34 #float
b = True # bool
s ="wassup" # str
lst  = [2,34,56,4] #list
t  = (1,2,3)#tuple
st ={12,44,56,4} # set
d = {a:"34"} #dict
int("12") #12
str(23.334) # "23.334"
# Out:
# '23.334'

# %%
#strings
s = " hello,world  "
print(s.strip())
print(s.upper())
print(s.split(","))
# Out:
# hello,world
#  HELLO,WORLD
# [' hello', 'world  ']

# %%
#String formatting
name = " derric "
age = 22
print(f" my name is {name} and i am {age} years old")
# Out:
#  my name is  derric  and i am 22 years old

# %%
pi= 3.124545344
print(f"pi is 2 decimals precise here :{pi:.2f}")
# Out:
# pi is 2 decimals precise here :3.12

# %%
x = 10
y = 3
print(x//y ,x%y,x**2)
print(x>y  and y>0)
# Out:
# 3 1 100
# True

# %%
#conditionals
x = 10
if x>5:
    print("big")
elif x ==5:
    print("Its equal")
else:
    print("it is small")
# Out:
# big

# %%
#ternary
x = 20
status = "even" if x%2 ==0 else "odd"
print(status)
# Out:
# even
